# %% [markdown]
# <img src="https://maestriasydiplomadostec.blob.core.windows.net/maestriasydiplomados/uploads/escuela_posgrado/logo/6/ingenieria.jpg" alt="HTML5" style="width:500px;height:100px">
#
# # **Herramientas computacionales: el arte de la analítica**
#
# *Grupo:* TC1002S.115
#
# *Liga Canvas:* https://experiencia21.tec.mx/courses/405474/
#
#
# *Alumno*
# <ul>
#   <li>Román Mauricio Elias Valencia - <a href="mailto:a01656603@tec.mx">a01656603@tec.mx</a></li>
# </ul>
#
# *Profesor*
# <ul>
#   <li>José Ángel Martínez Navarro - <a href="mailto:josekun13@tec.mx">josekun13@tec.mx</a></li>
# </ul>

# %%
import pandas as pd

# %%
file=open("covid19_tweets.csv","r")

linea1=file.readline().rstrip()
file.close()

print(linea1)
# Out:
# user_name,user_location,user_description,user_created,user_followers,user_friends,user_favourites,user_verified,date,text,hashtags,source,is_retweet

# %%
df=pd.read_csv("covid19_tweets.csv")
df
# Out:
#                       user_name         user_location  \
# 0                        ᏉᎥ☻լꂅϮ            astroworld
# 1                 Tom Basile 🇺🇸          New York, NY
# 2               Time4fisticuffs      Pewee Valley, KY
# 3                   ethel mertz  Stuck in the Middle
# 4                      DIPR-J&K     Jammu and Kashmir
# ...                         ...                   ...
# 74431             Laura Wolfrom         Lexington, KY
# 74432  Professor Tonya M. Evans         😷 #stayathome
# 74433        People's Daily app           北京, 中华人民共和国
# 74434                     M0ser                   NaN
# 74435    Your Friend & Sabre ⚔️           Chicago, IL
#
#                                         user_description         user_created  \
# 0      wednesday addams as a disney princess keepin i...  2017-05-26 05:46:42
# 1      Husband, Father, Columnist & Commentator. Auth...  2009-04-16 20:06:23
# 2      #Christian #Catholic #Conservative #Reagan #Re...  2009-02-28 18:57:41
# ...

# %%
df.head()
# Out:
#          user_name         user_location  \
# 0           ᏉᎥ☻լꂅϮ            astroworld
# 1    Tom Basile 🇺🇸          New York, NY
# 2  Time4fisticuffs      Pewee Valley, KY
# 3      ethel mertz  Stuck in the Middle
# 4         DIPR-J&K     Jammu and Kashmir
#
#                                     user_description         user_created  \
# 0  wednesday addams as a disney princess keepin i...  2017-05-26 05:46:42
# 1  Husband, Father, Columnist & Commentator. Auth...  2009-04-16 20:06:23
# 2  #Christian #Catholic #Conservative #Reagan #Re...  2009-02-28 18:57:41
# 3  #Browns #Indians #ClevelandProud #[]_[] #Cavs ...  2019-03-07 01:45:06
# 4  🖊️Official Twitter handle of Department of Inf...  2017-02-12 06:45:15
#
#    user_followers  user_friends  user_favourites  user_verified  \
# 0             624           950            18775          False
# 1            2253          1677               24           True
# 2            9275          9525             7254          False
# ...

# %%
df.tail()
# Out:
#                       user_name  user_location  \
# 74431             Laura Wolfrom  Lexington, KY
# 74432  Professor Tonya M. Evans  😷 #stayathome
# 74433        People's Daily app    北京, 中华人民共和国
# 74434                     M0ser            NaN
# 74435    Your Friend & Sabre ⚔️    Chicago, IL
#
#                                         user_description         user_created  \
# 74431            The only things I collect are memories.  2010-09-24 02:01:15
# 74432  Law Prof @DickinsonLaw & Entrepreneur | Crypto...  2013-05-14 20:15:24
# 74433  Our mission is to provide news and perspective...  2018-02-04 12:36:42
# 74434  Reagan conservative and attorney raised in the...  2014-02-18 03:46:28
# 74435  My spectral decomposition has a significant da...  2016-12-19 19:55:00
#
#        user_followers  user_friends  user_favourites  user_verified  \
# 74431              85           586             1902          False
# 74432            4289          1066            53569          False
# ...

# %%
df.columns
# Out:
# Index(['user_name', 'user_location', 'user_description', 'user_created',
#        'user_followers', 'user_friends', 'user_favourites', 'user_verified',
#        'date', 'text', 'hashtags', 'source', 'is_retweet'],
#       dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=74436, step=1)

# %%
r1=df.shape
r2=df.head()
r3=df.dtypes

max=df.iloc[:,4:7].max()
min=df.iloc[:,4:7].min()

media=df.iloc[:,4:7].mean()
mediana=df.iloc[:,4:7].median()
desvest=df.iloc[:,4:7].std()

# %%
print("Cantidad de filas y columnas:",r1)
# Out:
# Cantidad de filas y columnas: (74436, 13)

# %%
print("Variables que contiene cada vector de datos:\n",r2)
# Out:
# Variables que contiene cada vector de datos:
#           user_name         user_location  \
# 0           ᏉᎥ☻լꂅϮ            astroworld
# 1    Tom Basile 🇺🇸          New York, NY
# 2  Time4fisticuffs      Pewee Valley, KY
# 3      ethel mertz  Stuck in the Middle
# 4         DIPR-J&K     Jammu and Kashmir
#
#                                     user_description         user_created  \
# 0  wednesday addams as a disney princess keepin i...  2017-05-26 05:46:42
# 1  Husband, Father, Columnist & Commentator. Auth...  2009-04-16 20:06:23
# 2  #Christian #Catholic #Conservative #Reagan #Re...  2009-02-28 18:57:41
# 3  #Browns #Indians #ClevelandProud #[]_[] #Cavs ...  2019-03-07 01:45:06
# 4  🖊️Official Twitter handle of Department of Inf...  2017-02-12 06:45:15
#
#    user_followers  user_friends  user_favourites  user_verified  \
# 0             624           950            18775          False
# 1            2253          1677               24           True
# ...

# %%
print("Tipo de variables:\n",r3)
# Out:
# Tipo de variables:
#  user_name           object
# user_location       object
# user_description    object
# user_created        object
# user_followers       int64
# user_friends         int64
# user_favourites      int64
# user_verified         bool
# date                object
# text                object
# hashtags            object
# source              object
# is_retweet            bool
# dtype: object

# %%
print("Máximo:\n",max)
print("\nMínimo:\n",min)
# Out:
# Máximo:
#  user_followers     13892841
# user_friends         497363
# user_favourites     2047197
# dtype: int64
#
# Mínimo:
#  user_followers     0
# user_friends       0
# user_favourites    0
# dtype: int64

# %%
print("Media:\n",media)
print("\nMediana:\n",mediana)
print("\nDesviación estandar:\n",desvest)
# Out:
# Media:
#  user_followers     105951.312913
# user_friends         2154.721170
# user_favourites     15297.472030
# dtype: float64
#
# Mediana:
#  user_followers      960.0
# user_friends        552.0
# user_favourites    1927.0
# dtype: float64
#
# Desviación estandar:
#  user_followers     822289.985493
# user_friends         9365.587474
# user_favourites     46689.714291
# dtype: float64

# %% [markdown]
# En conclusión podemos decir que hubo una cantidad grande de alcance entre las interacciones de los usuarios y la actividad referente al COVID 19, los valores dicen que hubo una gran cantidad de usuarios interesados en este tema.
