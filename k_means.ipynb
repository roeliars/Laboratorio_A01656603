# %% [markdown]
# <img src="https://maestriasydiplomadostec.blob.core.windows.net/maestriasydiplomados/uploads/escuela_posgrado/logo/6/ingenieria.jpg" alt="HTML5" style="width:500px;height:100px">
#
# # **Herramientas computacionales: el arte de la analítica**
# # Actividad Evaluable: Patrones con K-means
#
#
# *Grupo:* TC1002S.115
#
# *Liga Canvas:* https://experiencia21.tec.mx/courses/405474/
#
#
# *Alumno*
# <ul>
#   <li>Román Mauricio Elias Valencia - <a href="mailto:a01656603@tec.mx">a01656603@tec.mx</a></li>
#   <li>María Esther Ramírez Cedillo - <a href="mailto:a01656060@tec.mx">a01656060@tec.mx</a></li>
#   <li>David González Alanis - <a href="mailto:a01661650@tec.mx">a01661650@tec.mx</a></li>
# </ul>
#
# *Profesor*
# <ul>
#   <li>José Ángel Martínez Navarro - <a href="mailto:josekun13@tec.mx">josekun13@tec.mx</a></li>
# </ul>

# %%
import pandas as pd
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

df = pd.read_csv('covid19_tweets.csv')

var=[]
for j in range(len(df["user_followers"])):
  var.append([df["user_followers"][j],df["user_favourites"][j]])


var2=np.array(var)
plt.scatter(var2[:,0],var2[:,1])

# %%
k_means = KMeans(n_clusters=3)
k_means.fit(var2)
centroides = k_means.cluster_centers_
etiquetas = k_means.labels_


plt.plot(var2[etiquetas==0,0],var2[etiquetas==0,1],'r.', label='cluster 1')
plt.plot(var2[etiquetas==1,0],var2[etiquetas==1,1],'b.', label='cluster 2')
plt.plot(var2[etiquetas==2,0],var2[etiquetas==2,1],'g.', label='cluster 3')

plt.plot(centroides[:,0],centroides[:,1],'mo',markersize=8, label='centroides')

plt.legend(loc='best')
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %% [markdown]
# #Preguntas
#
# 1.   ¿Crees que estos centros puedan ser representativos de los datos? ¿Por qué?
#
# Creemos que los centros si son representativos, ya que nos permiten ver una clara distribución de los datos, separando los datos en tres grupos, siendo la gente con pocos seguidores, que son la mayoría, los usuarios promedio y los usuarios con mucha influencia
#
# 2.   ¿Cómo obtuviste el valor de k a usar?
#
# Decidimos utilizar 3 clusters para que la gráfica mantenga claridad y muestre una separación evidente de los usuarios de Twitter
#
# 3.   ¿Los centros serían más representativos si usaras un valor más alto? ¿Más bajo?
#
# Los centros serían más representativos si fueran muchos más, esto se debe a que los datos estarían distribuidos de manera uniforme, permitiendo un análisis más profundo
#
# 4.   ¿Qué distancia tienen los centros entre sí? ¿Hay alguno que este muy cercano a otros?
#
# los centros tienen una distancia similar, pero los centros de los clusters 1 y 2 están más cerca que el tercer centro.
#
# 5.   ¿Qué pasaría con los centros si tuviéramos muchos outliers en el análisis de cajas y bigotes?
#
# En este análisis de datos podemos ver como existen multiples outliers, esto genera que los datos no se distribuyan de forma uniforme y los clusters queden de un tamaño disparejo. Entre más outliers haya, mayor será esta desorganización
#
# 6.   ¿Qué puedes decir de los datos basándose en los centros?
#
# Cluster 1 (rojo): Este cluster tiene un gran número de puntos de datos que están densamente agrupados. El centroide que estas cuentas tienen un número moderado de seguidores y favoritos. Podría representar a usuarios promedio en Twitter.
#
# Cluster 2 (azul): Este cluster tiene un número menor de puntos de datos que están más dispersos. El centroide indica que estas cuentas tienen un alto número de seguidores y una cantidad considerable de favoritos. Podría representar a usuarios populares o cuentas de celebridades.
#
# Cluster 3 (verde): Este cluster tiene un número muy pequeño de puntos de datos que están estrechamente agrupados. El centroide sugiere que estas cuentas tienen un número extremadamente alto de seguidores y favoritos. Podría representar a superusuarios o mega celebridades en Twitter.
